# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import datasets
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import OneHotEncoder,LabelEncoder
# %matplotlib inline
import pandas as pd
import pylab
from matplotlib.mlab import PCA as mlabPCA

# %% [markdown]
# ### Очистка данных

# %%
def clean_df(df, x=1, y=15): 
    #Чистим изначальный массив, берем определенное количество спикеров, по частоте их выступлений
    
    ind = df.Speaker.value_counts()[x:y].index # берем имена спикеров
        
    new_df=df[df.Speaker==ind[0]] # первый элемент дата фрейма 
    for i in range(1,len(ind)): # проходим по остальным элементам
        new_df=pd.concat([new_df,df[df.Speaker==ind[i]]]) # добавляем последующие подмассивы в основной

    return new_df # выводим

# %%
data = pd.read_csv('primary_debates_cleaned.csv')
df = clean_df(data)
train = df.Text.values

# %% [markdown]
# ### Векторизация данных

# %%
count_vect = CountVectorizer() 
X_train_counts = count_vect.fit_transform(train)

tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
vecs = X_train_tfidf

# %%
LE = LabelEncoder()
Y = df.Speaker.values
Y = LE.fit_transform(Y)
vecs = vecs.toarray()
X_train_counts = X_train_counts.toarray()

# %% [markdown]
# ### Разложение с помощью МГК после векторизации до  tfidf_transformer

# %%
pca = PCA(n_components=10)
pca.fit(X_train_counts)
X_reduced = pca.transform(X_train_counts)
# Out:
# PCA(copy=True, n_components=10, whiten=False)

# %%
plt.figure(figsize=(10,5))
plt.bar(np.arange(len(pca.explained_variance_)), pca.explained_variance_, facecolor='#9999ff', edgecolor='white',label="explained variance")
for x,y in zip(np.arange(len(pca.explained_variance_)),pca.explained_variance_):
    plt.text(x+0.4, y+0.0005, '%.2f' % y, ha='center', va= 'bottom')
plt.legend(loc='upper right')

# %%
fig = plt.figure(10, figsize=(9, 6))
ax = Axes3D(fig, elev=-150, azim=110)
ax.scatter(X_reduced[:, 1], X_reduced[:, 2], X_reduced[:, 3],cmap="gist_rainbow",c=Y)
ax.set_title("First three PCA directions for Vectorized text")
ax.set_xlabel("2nd eigenvector")
ax.w_xaxis.set_ticklabels([])
ax.set_ylabel("3-rd eigenvector")
ax.w_yaxis.set_ticklabels([])
ax.set_zlabel("4th eigenvector")
ax.w_zaxis.set_ticklabels([])
# Out:
# []

# %%
plt.figure(1, figsize=(9, 6))
pylab.scatter(X_reduced[:, 0], X_reduced[:, 1],cmap='gist_rainbow', c=Y,label="First two PCA directions for Vectorized text")

plt.legend(loc='upper right')
#cmap=plt.cm.Paired - отвечает за цветовую гамму

# %% [markdown]
# ### Разложение в МГК после  tfidf_transformer

# %%
pca = PCA(n_components=10)
pca.fit(vecs)
X_reduced = pca.transform(vecs)

# %%
plt.bar(np.arange(len(pca.explained_variance_)), pca.explained_variance_, facecolor='#9999ff', edgecolor='white',label="explained variance")
for x,y in zip(np.arange(len(pca.explained_variance_)),pca.explained_variance_):
    plt.text(x+0.4, y+0.0005, '%.2f' % y, ha='center', va= 'bottom')
plt.legend(loc='upper right')

# %%
fig = plt.figure(10, figsize=(9, 6))
ax = Axes3D(fig, elev=-150, azim=110)
ax.scatter(X_reduced[:, 1], X_reduced[:, 4], X_reduced[:, 3],cmap="gist_rainbow",c=Y)
ax.set_title("First three PCA directions for tfidf text")
ax.set_xlabel("5th eigenvector")
ax.w_xaxis.set_ticklabels([])
ax.set_ylabel("1st eigenvector")
ax.w_yaxis.set_ticklabels([])
ax.set_zlabel("4th eigenvector")
ax.w_zaxis.set_ticklabels([])

# %%
plt.figure(1, figsize=(9, 6))
pylab.scatter(X_reduced[:, 0], X_reduced[:, 1],cmap=plt.cm.Paired, c=Y,label="First two PCA directions for tfidf text")
plt.legend(loc='upper right')

# %%
fig = plt.figure(10, figsize=(9, 6))
ax = Axes3D(fig, elev=-150, azim=110)
ax.scatter(X_reduced[1:100, 1], X_reduced[1:100, 2], X_reduced[1:100, 3],cmap=plt.cm.Paired)

# %%
from mpl_toolkits.mplot3d import proj3d
fig = pylab.figure()
ax = fig.add_subplot(111, projection = '3d')
x = y = z = [1, 2, 3]
sc = ax.scatter(X_reduced[:, 1], X_reduced[:, 4], X_reduced[:, 3])
# now try to get the display coordinates of the first point

x2, y2, _ = proj3d.proj_transform(X_reduced[1, 1], X_reduced[1, 4], X_reduced[1, 3], ax.get_proj())

label = pylab.annotate(
    "this", 
    xy = (x2, y2), xytext = (-20, 20),
    textcoords = 'offset points', ha = 'right', va = 'bottom',
    bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.5),
    arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))


pylab.show()

# %%
ax = Axes3D(fig)
for i in range(len(X_reduced[:, 1])): #plot each point + it's index as text above
    ax.scatter(X_reduced[:, 1], X_reduced[:, 4], X_reduced[:, 3],color='b') 
    ax.text(X_reduced[:, 1], X_reduced[:, 4], X_reduced[:, 3],  '%s' % (str(i)), size=20, zorder=1,  
    color='k')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-1190ae7c7aa5> in <module>()
#       1 ax = Axes3D(fig)
#       2 for i in range(len(X_reduced[:, 1])): #plot each point + it's index as text above
# ----> 3     ax.scatter(X_reduced[:, 1], X_reduced[:, 4], X_reduced[:, 3],color='b')
#       4     ax.text(X_reduced[:, 1], X_reduced[:, 4], X_reduced[:, 3],  '%s' % (str(i)), size=20, zorder=1,
#       5     color='k')
#
# C:\Users\Piboditheowl\Anaconda2\lib\site-packages\mpl_toolkits\mplot3d\axes3d.pyc in scatter(self, xs, ys, zs, zdir, s, c, depthshade, *args, **kwargs)
#    2275             xs, ys, zs, s = cbook.delete_masked_points(xs, ys, zs, s)
#    2276
# -> 2277         patches = Axes.scatter(self, xs, ys, s=s, c=c, *args, **kwargs)
#    2278         if not cbook.iterable(zs):
#    2279             is_2d = True
#
# C:\Users\Piboditheowl\Anaconda2\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1816                     warnings.warn(msg % (label_namer, func.__name__),
#    1817                                   RuntimeWarning, stacklevel=2)
# -> 1818             return func(ax, *args, **kwargs)
#    1819         pre_doc = inner.__doc__
#    1820         if pre_doc is None:
#
# C:\Users\Piboditheowl\Anaconda2\lib\site-packages\matplotlib\axes\_axes.pyc in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    3836
#    3837         # c will be unchanged unless it is the same length as x:
# -> 3838         x, y, s, c = cbook.delete_masked_points(x, y, s, c)
#    3839
#    3840         scales = s   # Renamed for readability below.
#
# C:\Users\Piboditheowl\Anaconda2\lib\site-packages\matplotlib\cbook.pyc in delete_masked_points(*args)
#    1851     seqlist = [False] * len(args)
#    1852     for i, x in enumerate(args):
# -> 1853         if (not is_string_like(x)) and iterable(x) and len(x) == nrecs:
#    1854             seqlist[i] = True
#    1855             if ma.isMA(x):
#
# C:\Users\Piboditheowl\Anaconda2\lib\site-packages\matplotlib\cbook.pyc in iterable(obj)
#     691     except TypeError:
#     692         return False
# --> 693     return True
#     694
#     695
#
# KeyboardInterrupt:
